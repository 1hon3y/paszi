# %% [markdown]
# # Garbage collecion: сборка мусора (Модуль gc)

# %% [markdown]
# Модуль __gc__ предоставляет базовый механизм управления памятью в Python — автоматическую сборку мусора. Он включает функции, позволяющие принудительно вызывать сборщик мусора и исследовать известные системе объекты, которые либо намечены для удаления, либо связаны циклическими ссылками и не могут быть освобождены.

# %% [markdown]
# ## Отслеживание ссылок

# %% [markdown]
# Анализируя существующие между объектами входящие и исходящие ссылки, модуль __gc__ способен выявлять наличие циклических ссылок в сложных структурах данных. Если речь идет о циклических ссылках в известной структуре, то ее свойства могут быть исследованы c помощью пользовательского кода. Если же циклические ссылки появляются в неизвестном коде, то для создания обобщенных средств отладки можно использовать функции:

# %% [raw]
# get_referents()
# get_referrers()

# %% [markdown]
# Например, функция __get_referents()__ отображает объекты, на которые ссылаются входные аргументы.

# %%
import gc
import pprint

class Graph:
    
    def __init__(self, name):
        self.name = name
        self.next = None
        
    def set_next(self, next):
        print ('Linking nodes {}.next={}' .format(self, next))
        self.next = next
        
    def __repr__(self):
        return '{}({})' .format(
            self.__class__.__name__, self.name) 
    
#Cоздать циклический граф
one = Graph('one')
two = Graph('two')
three = Graph('three')

one.set_next(two)
two.set_next(three)
three.set_next(one)

print()
print('three refers to:')
for r in gc.get_referents(three):
    pprint.pprint(r)
# Out:
# Linking nodes Graph(one).next=Graph(two)
# Linking nodes Graph(two).next=Graph(three)
# Linking nodes Graph(three).next=Graph(one)
#
# three refers to:
# {'name': 'three', 'next': Graph(one)}
# <class '__main__.Graph'>

# %% [markdown]
# В данном случае экземпляр three класса Graph содержит ссылки на свой словарь и свой класс.

# %% [markdown]
# ## Принудительная сборка мусора

# %% [markdown]
# Несмотря на то, что сборщик мусора выполняется автоматически по мере выполнения программы интерпретатором, его можно запускать в определенные моменты времени, если необходимо освободить память от большого количества ненужных объектов или если выполняется лишь небольшой объем полезной работы и запуск сборщика не повлияет на производительность программы.
# Для этого следует использовать функцию __collect()__

# %%
import gc
import pprint

class Graph:
    
    def __init__(self, name):
        self.name = name
        self.next = None
        
    def set_next(self, next):
        print ('Linking nodes {}.next={}' .format(self, next))
        self.next = next
        
    def __repr__(self):
        return '{}({})' .format(
            self.__class__.__name__, self.name) 
    
#Cоздать циклический граф
one = Graph('one')
two = Graph('two')
three = Graph('three')

one.set_next(two)
two.set_next(three)
three.set_next(one)

# Удалить ссылки на узлы графа в пространстве имен данного модуля
one = two = three = None

# Продемонстрировать эффект сборки мусора
for i in range(2):
    print('\nCollecting {} ...'.format(i))
    n = gc.collect()
    print('Unreachable objects:', n)
    print('Remaining Garbage:', end=' ')
    pprint.pprint(gc.garbage)
# Out:
# Linking nodes Graph(one).next=Graph(two)
# Linking nodes Graph(two).next=Graph(three)
# Linking nodes Graph(three).next=Graph(one)
#
# Collecting 0 ...
# Unreachable objects: 36
# Remaining Garbage: []
#
# Collecting 1 ...
# Unreachable objects: 0
# Remaining Garbage: []

# %% [markdown]
# В этом примере цикл удаляется сразу же, как только выполняется сборка мусора, поскольку на узлы Graph не ссылаются никакие другие объекты, кроме них самих. Функция __collect()__ возвращает количество “недостижимых” объектов, которые ей удалось обнаружить. В данном случае это значение представляет три объекта c их словарями атрибутов экземпляров.

# %% [markdown]
# ## Пороги и поколения сборки мусора

# %% [markdown]
# Сборщик мусора поддерживает три списка объектов — по одному на каждое поколение сборки, отслеживаемое им. В процессе просмотра объектов в каждом поколении они либо удаляются, либо переводятся в следующее поколение, пока окончательно не достигнут состояния, в котором они постоянно находятся.
# Выполняемые сборщиком рутинные операции можно настраивать так, чтобы они осуществлялись c различной частотой на основании разницы между количествами размещаемых и удаляемых объектов от запуска к запуску. Если количество размещений объектов минус количество удалений превышает установленный для
# данного поколения порог, запускается сборщик мусора. Для получения текущих пороговых значений следует использовать функцию __get_threshold()__

# %%
import gc

print(gc.get_threshold())
# Out:
# (700, 10, 10)

# %% [markdown]
# Возвращаемое значение представляет собой кортеж из пороговых значений для каждого поколения.

# %% [markdown]
# Для изменения пороговых значений следует использовать функцию __set_threshold()__. В следующем примере программа устанавливает для поколения 0 пороговое значение, заданное аргументом командной строки, а затем размещает в памяти последовательность объектов.

# %%
import gc
import pprint
import sys

try:
    threshold = int(sys.argv[1])
except (IndexError, ValueError, TypeError):
    print('Missing or invalid threshold, using default')
    threshold = 2

          
class MyObj:
          
    def __init__ (self, name):
        self.name = name
        print('Created', self.name)
          
gc.set_debug(gc.DEBUG_STATS)
gc.set_threshold(threshold, 1, 1)
print('Thresholds:', gc.get_threshold())
          
print('Clear the collector by forcing a run')
gc.collect()
print()
          
print('Creating objects')
objs = []
for i in range(10):
    objs.append(MyObj(i))
print('Exiting')
          
# Отключить отладку
gc.set_debug(0)
# Out:
# Missing or invalid threshold, using default
# Thresholds: (2, 1, 1)
# Clear the collector by forcing a run
#
# Creating objects
# gc: collecting generation 0...
# gc: objects in each generation: 26 0 50936
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 28 50936
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 34 0 50977
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 17 31 50957
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 18 47 50950
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51019
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51019
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 51019
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51058
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 16 51055
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 29 51053
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51095
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 12 51078
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 29 50917
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50960
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 50960
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 27 50960
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50998
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 50998
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 12 50932
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 50958
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 13 50958
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 25 50957
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50995
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 13 50995
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 27 50995
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 0 51035
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 12 51034
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 11 50932
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50944
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 50944
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 27 50944
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 23 0 50935
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 27 50935
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 40 50935
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50988
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 50988
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 50988
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51027
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51027
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 14 24 51011
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51050
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 12 50932
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 26 50932
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 0 50942
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 16 50942
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 29 50942
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 15 0 50975
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 18 17 50975
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 39 50975
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51027
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51027
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 17 2 50941
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50964
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 12 50947
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 2...
# gc: objects in each generation: 8 13 50929
# gc: objects in permanent generation: 0
# gc: done, 18 unreachable, 0 uncollectable, 0.0160s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 20 0 50908
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 24 50908
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 36 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50955
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 50955
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 15 25 50954
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50998
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 13 50998
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 25 50998
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51075
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51075
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 51075
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51114
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51114
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 24 51109
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51145
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 13 51145
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 26 51145
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 0 51176
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 12 51174
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 10 50912
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 0 50918
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 15 50918
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 28 50918
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50959
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 50959
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 23 10 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50941
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 11 50919
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 24 50919
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50956
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 50956
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 12 50922
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50947
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 12 50930
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 27 50930
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50971
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 50971
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 27 50971
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51009
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51009
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 26 51009
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 13 0 50915
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 23 14 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 41 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50958
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 50958
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 50958
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 50923
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 15 50923
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 28 50923
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 0 50946
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 24 12 50931
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 40 50931
# gc: objects in permanent generation: 0
# Created 0
# Created 1
# Created 2
# Created 3
# Created 4
# Created 5
# Created 6
# Created 7
# Created 8
# Created 9
# Exiting
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50935
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 28 50918
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 41 50918
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 50964
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 26 50963
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 39 50963
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51003
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 12 51001
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 12 24 50997
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 13 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 26 51036
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51075
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 51075
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 8 30 51070
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 51112
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 14 51112
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 27 51111
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 0 51151
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 13 51151
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 39 51099
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 0 51151
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 12 51150
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 25 51150
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50922
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 20 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 12 18 50902
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 50924
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 18 50902
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 21 50902
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 50925
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 18 50903
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 22 50903
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 0 50921
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 22 50903
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 12 18 50903
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 50937
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 13 50937
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 9 25 50936
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 10 0 50973
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 9 14 50973
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 27 50973
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 0 51014
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 18 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 34 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 8 0 50951
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 18 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 11 22 50904
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 159 0 50617
# gc: objects in permanent generation: 0

# %% [markdown]
# Изменение пороговых значений влияет на то, в какие моменты времени будет выполняться сборка мусора. При меньших пороговых значениях сборка мусора выполняется чаще.

# %% [markdown]
# ## Отладка

# %% [markdown]
# Обнаружение причин утечки памяти может оказаться трудной задачей. Модуль gc предоставляет несколько отладочных опций, которые упрощают решение этой задачи, позволяя увидеть детали работы внутренних механизмов кода. Указанные опции представляют собой битовые флаги, которые можно комбинировать и передавать функции __set_debug()__ для управления поведением сборщика мусора во время выполнения программы. Отладочная информация выводится в поток __sys.stderr__.
#
#
# Флаг __DEBUG_STATS__ включает вывод статистики, вынуждая механизм сборщика мусора выводить в процессе своего выполнения информацию о том, сколько объектов отмечено для помещения в каждое поколение и сколько времени требуется для очистки памяти.

# %%
import gc

gc.set_debug(gc.DEBUG_STATS)

gc.collect()
print('Exiting')
# Out:
# Exiting
# gc: collecting generation 0...
# gc: objects in each generation: 26 0 50747
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 28 50747
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 2...
# gc: objects in each generation: 13 27 50747
# gc: objects in permanent generation: 0
# gc: done, 26 unreachable, 0 uncollectable, 0.0160s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 24 0 50754
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 16 23 50754
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 25 43 50753
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 16 0 50817
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 11 25 50803
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 10 40 50803
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 0 50850
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 15 15 50836
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 14 34 50836
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 0 50885
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 23 15 50803
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 27 39 50719
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 16 0 50782
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 33 15 50677
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 37 8 50641
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 30 0 50682
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 22 2 50646
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 20 18 50641
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 14 0 50681
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 19 17 50681
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 18 39 50680
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 31 0 50678
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 30 29 50676
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 17 41 50676
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 34 0 50717
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 12 28 50717
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 17 44 50716
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 48 0 50702
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 28 6 50608
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 12 38 50608
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 17 0 50658
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 0...
# gc: objects in each generation: 17 8 50627
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed
# gc: collecting generation 1...
# gc: objects in each generation: 13 29 50627
# gc: objects in permanent generation: 0
# gc: done, 0 unreachable, 0 uncollectable, 0.0000s elapsed

# %% [markdown]
# Флаги __DEBUG_COLLECTABLE__ и __DEBUG_UNCOLLECTABLE__ вынуждают сборщик мусора выводить информацию о том, может или не может быть удален проверяемый объект. Если информации об объектах, которые не могут быть удалены, еще недостаточно для того, чтобы определить, где именно удерживаются данные, следует установить флаг __DEBUG_SAVEALL__, вынуждающий модуль gc сохранить все обнаруженные объекты, на которые отсутствуют ссылки, в списке __garbage__.

# %%
import gc
flags = gc.DEBUG_LEAK

gc.set_debug(flags)

class Graph:
    
    def __init__(self, name):
        self.name = name
        self.next = None
        
    def set_next(self, next):
        self.next = next
        
    def __repr__(self) :
        return '{}({})'.format(
            self.__class__.__name__, self.name)

class CleanupGraph(Graph):
    
    def __del__(self) :
        print('{}.__del__()'.format(self))
              
# Создать циклический граф
one = Graph('one')
two = Graph('two')
one.set_next(two)
two.set_next(one)
            
# Создать самостоятельный узел
three = CleanupGraph('three')
                     
# Создать циклический граф c помощью финализатора
four = CleanupGraph('four')
five = CleanupGraph('five')
four.set_next(five)
five.set_next(four)
                    
# Удалить ссылки на узлы графа в пространстве имен этого модуля
one = two = three = four = five = None
                    
# Принудительный запуск сборщика мусора
print('Collecting')
gc.collect ()
print('Done')
      
# Вывести информацию об оставшихся объектах
for o in gc.garbage:
    if isinstance(o, Graph):
        print('Retained: {} Ox{:x}'.format(o, id(o)))
      
    
# Сбросить флаги отладки перед выходом    
gc.set_debug(0)
# Out:
# CleanupGraph(three).__del__()
# Collecting
# CleanupGraph(four).__del__()
# CleanupGraph(five).__del__()
# Done
# Retained: Graph(one) Ox1f0c7483f70
# Retained: Graph(two) Ox1f0c7483ee0
# Retained: CleanupGraph(four) Ox1f0c7483d90
# Retained: CleanupGraph(five) Ox1f0c7483640
# gc: collectable <Graph 0x000001F0C7456D00>
# gc: collectable <Graph 0x000001F0C7456D60>
# gc: collectable <Graph 0x000001F0C7456E50>
# gc: collectable <dict 0x000001F0C7477C80>
# gc: collectable <dict 0x000001F0C7477E80>
# gc: collectable <dict 0x000001F0C7477DC0>
# gc: collectable <frame 0x000001F0C59B2120>
# gc: collectable <list 0x000001F0C7446900>
# gc: collectable <dict 0x000001F0C7477200>
# gc: collectable <dict 0x000001F0C747C240>
# gc: collectable <list 0x000001F0C743FE00>
# gc: collectable <type 0x000001F0C69D08F0>
# gc: collectable <dict 0x000001F0C7446280>
# gc: collectable <tuple 0x000001F0C73EC440>
# gc: collectable <function 0x000001F0C748B040>
# gc: collectable <getset_descriptor 0x000001F0C747CE40>
# gc: collectable <getset_descriptor 0x000001F0C747CF40>
# gc: collectable <ValueError 0x000001F0C5C50EA0>
# gc: collectable <traceback 0x000001F0C73EE5C0>
# gc: collectable <frame 0x000001F0C73A5C10>
# gc: collectable <ValueError 0x000001F0C5C50F40>
# gc: collectable <frame 0x000001F0C5ADE170>
# gc: collectable <frame 0x000001F0C6BB3A10>
# gc: collectable <traceback 0x000001F0C743F5C0>
# gc: collectable <frame 0x000001F0C6BB3190>
# gc: collectable <frame 0x000001F0C6BB59F0>
# gc: collectable <frame 0x000001F0C7468BA0>
# gc: collectable <traceback 0x000001F0C743F980>
# gc: collectable <traceback 0x000001F0C743F900>
# gc: collectable <traceback 0x000001F0C73EE480>
# gc: collectable <Graph 0x000001F0C7483F70>
# gc: collectable <Graph 0x000001F0C7483EE0>
# gc: collectable <dict 0x000001F0C7455580>
# gc: collectable <dict 0x000001F0C7455780>
# gc: collectable <CleanupGraph 0x000001F0C7483D90>
# gc: collectable <CleanupGraph 0x000001F0C7483640>
# gc: collectable <dict 0x000001F0C7455640>
# gc: collectable <dict 0x000001F0C7455280>

# %% [markdown]
# Для простоты определен флаг __DEBUG_LEAK__, представляющий комбинацию
# всех остальных опций. Он автоматически включает флаг __DEBUG_
# SAVEALL__, в связи c чем будут сохранены даже те объекты, на которые отсутствуют
# ссылки и которые в обычных условиях были бы затребованы сборщиком мусора
# и в конечном счете удалены.
